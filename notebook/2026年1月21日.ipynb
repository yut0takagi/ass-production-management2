# %% [markdown]
# ## `process_end_time`（ユニット）ごとのOV推移を時系列出力
#
# - **ユニット定義**: 同一の `process_end_time` を同一ユニットとして扱う
# - **時系列**: ユニット内を `final_mes_time` の昇順に並べたOVの推移
# - **出力**:
#   - 長形式: `data/processed/ov_timeseries_by_unit.csv`
#   - ユニット集計: 件数/期間/OV統計
#   - 代表ユニットの推移プロット（上位Nユニット）

# %%
cluster_num = 4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from IPython.display import display
import pathlib
import tqdm
import optuna
import pickle

from scipy.cluster.hierarchy import linkage, dendrogram
import statsmodels.api as sm
from statsmodels.tsa.ar_model import AutoReg

import lightgbm as lgb
from lightgbm import LGBMRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import RandomizedSearchCV, train_test_split, KFold
from sklearn.inspection import permutation_importance

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, WhiteKernel
from sklearn.cluster import AgglomerativeClustering
from sklearn.svm import SVR
from sklearn.linear_model import Lasso

from seaborn_analyzer import regplot
from lightgbm import LGBMRegressor

from utils.mmd import mmd_rbf_unbiased
from utils.slicedWassersteinDistance import sliced_wasserstein_distance

import xgboost as xgb
from xgboost import XGBRegressor

# %%
raw_data = pd.read_excel('../data/raw/kadai.xlsx')
plt.figure(figsize=(10, 5))
plt.plot(
    raw_data.index,
    raw_data["OV"],
    label="OV"
)
plt.show()

raw_data.head()
# Out:
#      process_end_time      final_mes_time        OV     X1    X2      X3  \
# 0 2016-08-14 23:07:00 2016-09-24 04:22:00  111.2886  22.98  1.37  797.20
# 1 2016-08-14 23:07:00 2016-09-24 10:12:00  201.5617  22.45  9.40  803.80
# 2 2016-08-14 23:07:00 2016-09-24 14:11:00  111.9410  22.03  1.14  594.52
# 3 2016-08-14 23:07:00 2016-09-24 15:30:00  182.3914  22.98  1.37  797.20
# 4 2016-08-14 23:07:00 2016-09-24 18:31:00  196.2703  22.98  1.37  797.20
#
#      X4    X5    X6     X7  ...  X74   X75  X76   X77  X78  X79  X80   X81  \
# 0  0.67  0.15  0.08  67.15  ...  0.1  0.04  6.4  0.58  0.0  4.1  0.0  0.01
# 1  0.68  0.15  0.08  56.11  ...  0.1  0.04  6.4  0.58  0.0  4.1  0.0  0.01
# 2  0.64  0.14  0.08  51.57  ...  0.1  0.04  6.4  0.58  0.0  4.1  0.0  0.01
# 3  0.67  0.15  0.08  67.15  ...  0.1  0.04  6.4  0.58  0.0  4.1  0.0  0.01
# 4  0.67  0.15  0.08  67.15  ...  0.1  0.04  6.4  0.58  0.0  4.1  0.0  0.01
#
#     X82   X83
# 0  0.16  0.04
# 1  0.16  0.04
# 2  0.16  0.04
# 3  0.16  0.04
# 4  0.16  0.04
#
# [5 rows x 86 columns]

# %%
train = raw_data[:-500]
train.tail()
# Out:
#         process_end_time      final_mes_time        OV     X1    X2      X3  \
# 1771 2016-11-28 07:26:00 2017-01-18 09:43:00  107.8289  23.62  9.35  705.91
# 1772 2016-11-28 07:26:00 2017-01-18 12:34:00  127.8525  23.62  9.35  705.91
# 1773 2016-11-28 07:26:00 2017-01-18 13:42:00  116.4156  23.62  9.35  705.91
# 1774 2016-11-28 07:26:00 2017-01-18 14:47:00  131.6603  23.62  9.35  705.91
# 1775 2016-11-28 07:26:00 2017-01-18 16:38:00  123.1508  23.62  9.35  705.91
#
#         X4    X5    X6      X7  ...   X74   X75  X76  X77  X78  X79   X80  \
# 1771  0.64  0.14  0.08  127.48  ...  0.03  0.26  6.5  0.2  0.0  2.7  0.02
# 1772  0.64  0.14  0.08  127.48  ...  0.03  0.26  6.5  0.2  0.0  2.7  0.02
# 1773  0.64  0.14  0.08  127.48  ...  0.03  0.26  6.5  0.2  0.0  2.7  0.02
# 1774  0.64  0.14  0.08  127.48  ...  0.03  0.26  6.5  0.2  0.0  2.7  0.02
# 1775  0.64  0.14  0.08  127.48  ...  0.03  0.26  6.5  0.2  0.0  2.7  0.02
#
#        X81   X82   X83
# 1771  0.01  0.25  0.04
# 1772  0.01  0.25  0.04
# 1773  0.01  0.25  0.04
# 1774  0.01  0.25  0.04
# 1775  0.01  0.25  0.04
#
# [5 rows x 86 columns]

# %%
train = train.copy()
train["batch_id"] = train.groupby("process_end_time").ngroup()
train.head()
# Out:
#      process_end_time      final_mes_time        OV     X1    X2      X3  \
# 0 2016-08-14 23:07:00 2016-09-24 04:22:00  111.2886  22.98  1.37  797.20
# 1 2016-08-14 23:07:00 2016-09-24 10:12:00  201.5617  22.45  9.40  803.80
# 2 2016-08-14 23:07:00 2016-09-24 14:11:00  111.9410  22.03  1.14  594.52
# 3 2016-08-14 23:07:00 2016-09-24 15:30:00  182.3914  22.98  1.37  797.20
# 4 2016-08-14 23:07:00 2016-09-24 18:31:00  196.2703  22.98  1.37  797.20
#
#      X4    X5    X6     X7  ...   X75  X76   X77  X78  X79  X80   X81   X82  \
# 0  0.67  0.15  0.08  67.15  ...  0.04  6.4  0.58  0.0  4.1  0.0  0.01  0.16
# 1  0.68  0.15  0.08  56.11  ...  0.04  6.4  0.58  0.0  4.1  0.0  0.01  0.16
# 2  0.64  0.14  0.08  51.57  ...  0.04  6.4  0.58  0.0  4.1  0.0  0.01  0.16
# 3  0.67  0.15  0.08  67.15  ...  0.04  6.4  0.58  0.0  4.1  0.0  0.01  0.16
# 4  0.67  0.15  0.08  67.15  ...  0.04  6.4  0.58  0.0  4.1  0.0  0.01  0.16
#
#     X83  batch_id
# 0  0.04         0
# 1  0.04         0
# 2  0.04         0
# 3  0.04         0
# 4  0.04         0
#
# [5 rows x 87 columns]

# %% [markdown]
# ## `batch_id==43`のデータの`std`がNaNになっている(レコード数1だから)

# %%
train.query("batch_id == 43").describe().T
# Out:
#                  count                           mean                  min  \
# process_end_time    25            2016-10-11 20:55:00  2016-10-11 20:55:00
# final_mes_time      25  2016-11-23 05:26:09.600000256  2016-11-21 11:54:00
# OV                25.0                     116.364666             72.25858
# X1                25.0                        22.5632                21.96
# X2                25.0                         2.0412                 1.23
# ...                ...                            ...                  ...
# X80               25.0                            0.0                  0.0
# X81               25.0                            0.0                  0.0
# X82               25.0                           0.23                 0.23
# X83               25.0                            0.0                  0.0
# batch_id          25.0                           43.0                 43.0
#
#                                   25%                  50%  \
# process_end_time  2016-10-11 20:55:00  2016-10-11 20:55:00
# final_mes_time    2016-11-21 19:44:00  2016-11-22 00:17:00
# OV                           97.68092              113.827
# X1                              21.96                23.12
# X2                               1.23                 2.79
# ...                               ...                  ...
# X80                               0.0                  0.0
# X81                               0.0                  0.0
# X82                              0.23                 0.23
# X83                               0.0                  0.0
# batch_id                         43.0                 43.0
#
#                                   75%                  max        std
# process_end_time  2016-10-11 20:55:00  2016-10-11 20:55:00        NaN
# final_mes_time    2016-11-22 08:04:00  2016-11-27 20:32:00        NaN
# OV                           131.5234             182.1575  26.804585
# X1                              23.12                23.12   0.591486
# X2                               2.79                 2.79   0.795447
# ...                               ...                  ...        ...
# X80                               0.0                  0.0        0.0
# X81                               0.0                  0.0        0.0
# X82                              0.23                 0.23        0.0
# X83                               0.0                  0.0        0.0
# batch_id                         43.0                 43.0        0.0
#
# [87 rows x 8 columns]

# %%
plt.figure(figsize=(10, 5))

for batch_id, g in train.groupby("batch_id"):
    plt.plot(
        g.index,
        g["OV"],
        label=f"batch {batch_id}"
    )

plt.xlabel("Index")
plt.ylabel("Value")
plt.title("Line plot colored by class_id (index order)")
plt.show()

# %%
group_max = train["batch_id"].max()
group_max
# Out:
# 75

# %%
target_cols = ["OV"]
train_group_describe = train.groupby("batch_id")[target_cols].describe()
train_group_describe.columns = [f"{col}_{stat}" for col, stat in train_group_describe.columns]

# 4) batch_id 0〜99 を揃える（欠番があっても行が揃う）
train_group_describe = train_group_describe.reindex(range(group_max +1))

train_group_describe.shape
# Out:
# (76, 8)

# %%
train_group_describe.head()
# Out:
#           OV_count     OV_mean     OV_std     OV_min      OV_25%     OV_50%  \
# batch_id
# 0             25.0  173.095301  53.414865   94.09462  117.061900  186.44740
# 1             50.0  241.289936  52.090579  135.92270  201.864800  237.02915
# 2             12.0  192.000583  18.030431  174.63060  178.607950  186.47455
# 3             24.0  163.060428  42.699022   94.99309  120.429150  178.57250
# 4             14.0  165.873057  20.871967  120.42570  155.393125  164.31325
#
#               OV_75%    OV_max
# batch_id
# 0         207.502800  272.5857
# 1         287.242875  323.5988
# 2         200.182675  232.7684
# 3         195.746475  219.1410
# 4         178.399150  205.5169

# %%
X= train_group_describe
sns.heatmap(X.isna(), cbar=False)
# Out:
# <Axes: ylabel='batch_id'>

# %%
X.tail(3)
# Out:
#           OV_count     OV_mean     OV_std     OV_min      OV_25%     OV_50%  \
# batch_id
# 73            19.0   71.020897  36.507742   37.50772   42.377095   50.41835
# 74            43.0   80.479239  17.281147   45.09756   75.760615   82.12382
# 75            10.0  123.481890  13.949862  107.27810  112.033275  121.57735
#
#              OV_75%    OV_max
# batch_id
# 73        102.96480  136.4957
# 74         90.23184  116.9339
# 75        130.70835  145.5511

# %%
# 欠損補完は前後の値の平均で（線形補間使用）
X.interpolate(method='linear', axis=0, inplace=True, limit_direction='both')

# %%
model = AgglomerativeClustering(
    n_clusters=cluster_num,
    metric="euclidean",
    linkage="ward"
)

model.fit(X)
# Out:
# AgglomerativeClustering(n_clusters=4)

# %%
len(model.labels_)
# Out:
# 76

# %%
# リンク関数で階層構造を生成（'ward'はユークリッド距離限定）
linked = linkage(X, method='ward')

plt.figure(figsize=(15, 5))
dendrogram(linked, labels=X.index)
plt.show()

# %%
X["labels"] = model.labels_
X
# Out:
#           OV_count     OV_mean     OV_std     OV_min      OV_25%     OV_50%  \
# batch_id
# 0             25.0  173.095301  53.414865   94.09462  117.061900  186.44740
# 1             50.0  241.289936  52.090579  135.92270  201.864800  237.02915
# 2             12.0  192.000583  18.030431  174.63060  178.607950  186.47455
# 3             24.0  163.060428  42.699022   94.99309  120.429150  178.57250
# 4             14.0  165.873057  20.871967  120.42570  155.393125  164.31325
# ...            ...         ...        ...        ...         ...        ...
# 71            18.0   89.303027  13.572619   67.48009   79.973772   90.89747
# 72            15.0   59.426841   7.920872   49.45166   52.418065   59.15161
# 73            19.0   71.020897  36.507742   37.50772   42.377095   50.41835
# 74            43.0   80.479239  17.281147   45.09756   75.760615   82.12382
# 75            10.0  123.481890  13.949862  107.27810  112.033275  121.57735
#
#               OV_75%     OV_max  labels
# batch_id
# 0         207.502800  272.58570       0
# 1         287.242875  323.59880       3
# 2         200.182675  232.76840       0
# 3         195.746475  219.14100       0
# 4         178.399150  205.51690       0
# ...              ...        ...     ...
# 71         97.881782  109.29320       1
# 72         63.681500   76.60797       1
# 73        102.964800  136.49570       1
# 74         90.231840  116.93390       1
# 75        130.708350  145.55110       2
#
# [76 rows x 9 columns]

# %%
train = train.merge(
    X[["labels"]],      # 付与したい列だけ
    left_on="batch_id",
    right_index=True,   # X は index が batch_id
    how="left"
)

# %%
for i in range(cluster_num):
    plt.figure(figsize=(9, 4))
    plt.plot(
        train.index,
        train["OV"],
        label='Actual OV',
        color='red',
        linestyle='--',
        alpha=0.3
    )
    # labelsが1のみフィルタしてプロット
    mask = train["labels"] == i
    plt.scatter(
        train.index[mask],
        train["OV"][mask],
        c=train["labels"][mask],
        cmap="tab10",
        s=10,
        zorder=2
    )

    plt.xlabel("record index")
    plt.ylabel("OV")
    plt.title(f"OV[cluster id:{i}] by record (colored by batch cluster)")
    plt.colorbar(label="cluster")

    plt.show()

# %% [markdown]
# ## trainデータにおけるクラス予測(説明変数: OV以外)

# %%
train.head(3)
# Out:
#      process_end_time      final_mes_time        OV     X1    X2      X3  \
# 0 2016-08-14 23:07:00 2016-09-24 04:22:00  111.2886  22.98  1.37  797.20
# 1 2016-08-14 23:07:00 2016-09-24 10:12:00  201.5617  22.45  9.40  803.80
# 2 2016-08-14 23:07:00 2016-09-24 14:11:00  111.9410  22.03  1.14  594.52
#
#      X4    X5    X6     X7  ...  X76   X77  X78  X79  X80   X81   X82   X83  \
# 0  0.67  0.15  0.08  67.15  ...  6.4  0.58  0.0  4.1  0.0  0.01  0.16  0.04
# 1  0.68  0.15  0.08  56.11  ...  6.4  0.58  0.0  4.1  0.0  0.01  0.16  0.04
# 2  0.64  0.14  0.08  51.57  ...  6.4  0.58  0.0  4.1  0.0  0.01  0.16  0.04
#
#    batch_id  labels
# 0         0       0
# 1         0       0
# 2         0       0
#
# [3 rows x 88 columns]

# %%
train_one_hot_encording = pd.get_dummies(train, drop_first=False, columns=['labels'])
train_one_hot_encording.head(3)
# Out:
#      process_end_time      final_mes_time        OV     X1    X2      X3  \
# 0 2016-08-14 23:07:00 2016-09-24 04:22:00  111.2886  22.98  1.37  797.20
# 1 2016-08-14 23:07:00 2016-09-24 10:12:00  201.5617  22.45  9.40  803.80
# 2 2016-08-14 23:07:00 2016-09-24 14:11:00  111.9410  22.03  1.14  594.52
#
#      X4    X5    X6     X7  ...  X79  X80   X81   X82   X83  batch_id  \
# 0  0.67  0.15  0.08  67.15  ...  4.1  0.0  0.01  0.16  0.04         0
# 1  0.68  0.15  0.08  56.11  ...  4.1  0.0  0.01  0.16  0.04         0
# 2  0.64  0.14  0.08  51.57  ...  4.1  0.0  0.01  0.16  0.04         0
#
#    labels_0  labels_1  labels_2  labels_3
# 0      True     False     False     False
# 1      True     False     False     False
# 2      True     False     False     False
#
# [3 rows x 91 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.inspection import permutation_importance
from sklearn.metrics import classification_report, confusion_matrix
import pandas as pd
import matplotlib.pyplot as plt

perm_importances = {}

for label_ in range(cluster_num):
    print(f"\n==== label_{label_} ============================================================")

    ignore_labels = [f"labels_{i}" for i in range(cluster_num)]
    ignore_cols = ['OV', "process_end_time", "final_mes_time", "batch_id", *ignore_labels]

    X = train_one_hot_encording.drop(columns=ignore_cols)
    y = train_one_hot_encording[f'labels_{label_}'].astype(int)  # bool→0/1に統一

    X_train, X_test, y_train, y_test = train_test_split(
        X, y,
        test_size=0.3,
        stratify=y,
        random_state=42
    )

    print("y overall:\n", y.value_counts())
    print("y train:\n", y_train.value_counts())
    print("y test:\n", y_test.value_counts())

    model = RandomForestClassifier(
        n_estimators=300,
        random_state=42,
        class_weight="balanced"   # 不均衡対策（効くこと多い）
    )
    model.fit(X_train, y_train)

    # 評価（分類）
    y_pred = model.predict(X_test)
    print("confusion matrix:\n", confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred, digits=3))

    # Permutation Importance（分類スコアで・テストで）
    r = permutation_importance(
        model,
        X_test, y_test,
        n_repeats=20,
        random_state=42,
        n_jobs=-1,
        scoring="f1"   # ここが重要（precision/recallでもOK）
    )

    perm = pd.Series(r.importances_mean, index=X.columns).sort_values(ascending=False)

    plt.figure(figsize=(8, 6))
    perm.head(5).sort_values().plot.barh()
    plt.title(f"Permutation Importance (label:{label_}, scoring=f1)")
    plt.xlabel("importance (ΔF1)")
    plt.show()

    perm_importances[label_] = perm.head(5).to_dict()

perm_importances
# Out:
# ==== label_0 ============================================================
# y overall:
#  labels_0
# 0    1049
# 1     727
# Name: count, dtype: int64
# y train:
#  labels_0
# 0    734
# 1    509
# Name: count, dtype: int64
# y test:
#  labels_0
# 0    315
# 1    218
# Name: count, dtype: int64
# confusion matrix:
#  [[310   5]
#  [  7 211]]
#               precision    recall  f1-score   support
#
#            0      0.978     0.984     0.981       315
#            1      0.977     0.968     0.972       218
#
#     accuracy                          0.977       533
#    macro avg      0.977     0.976     0.977       533
# weighted avg      0.977     0.977     0.977       533
# ==== label_1 ============================================================
# y overall:
#  labels_1
# 0    1221
# 1     555
# Name: count, dtype: int64
# y train:
#  labels_1
# 0    855
# 1    388
# Name: count, dtype: int64
# y test:
#  labels_1
# 0    366
# 1    167
# Name: count, dtype: int64
# confusion matrix:
#  [[366   0]
#  [  0 167]]
#               precision    recall  f1-score   support
#
#            0      1.000     1.000     1.000       366
#            1      1.000     1.000     1.000       167
#
#     accuracy                          1.000       533
#    macro avg      1.000     1.000     1.000       533
# weighted avg      1.000     1.000     1.000       533
# ==== label_2 ============================================================
# y overall:
#  labels_2
# 0    1500
# 1     276
# Name: count, dtype: int64
# y train:
#  labels_2
# 0    1050
# 1     193
# Name: count, dtype: int64
# y test:
#  labels_2
# 0    450
# 1     83
# Name: count, dtype: int64
# confusion matrix:
#  [[450   0]
#  [  0  83]]
#               precision    recall  f1-score   support
#
#            0      1.000     1.000     1.000       450
#            1      1.000     1.000     1.000        83
#
#     accuracy                          1.000       533
#    macro avg      1.000     1.000     1.000       533
# weighted avg      1.000     1.000     1.000       533
# ==== label_3 ============================================================
# y overall:
#  labels_3
# 0    1558
# 1     218
# Name: count, dtype: int64
# y train:
#  labels_3
# 0    1090
# 1     153
# Name: count, dtype: int64
# y test:
#  labels_3
# 0    468
# 1     65
# Name: count, dtype: int64
# confusion matrix:
#  [[459   9]
#  [  0  65]]
#               precision    recall  f1-score   support
#
#            0      1.000     0.981     0.990       468
#            1      0.878     1.000     0.935        65
#
#     accuracy                          0.983       533
#    macro avg      0.939     0.990     0.963       533
# weighted avg      0.985     0.983     0.984       533
# {0: {'X82': 0.007638213849114289,
#   'X80': 0.0040565049385662185,
#   'X77': 0.0013256140155864682,
#   'X1': 0.0,
#   'X48': 0.0},
#  1: {'X2': 0.0017883795309168505,
#   'X20': 0.0011931414356787574,
#   'X54': 0.0,
#   'X61': 0.0,
#   'X60': 0.0},
#  2: {'X72': 0.003304343433302398,
#   'X1': 0.0,
#   'X54': 0.0,
#   'X61': 0.0,
#   'X60': 0.0},
#  3: {'X76': 0.005782287754652599,
#   'X71': 0.004021534205420752,
#   'X1': 0.0,
#   'X53': 0.0,
#   'X60': 0.0}}

# %%
X = train[[f"X{i}" for i in range(1,84)]]
y = train[f'labels']

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.3,
    stratify=y,
    random_state=42
)

print("y overall:\n", y.value_counts())
print("y train:\n", y_train.value_counts())
print("y test:\n", y_test.value_counts())

model = RandomForestClassifier(
    n_estimators=300,
    random_state=42,
    class_weight="balanced"   # 不均衡対策（効くこと多い）
)
model.fit(X_train, y_train)

# 評価（分類）
y_pred = model.predict(X_test)
print("confusion matrix:\n", confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred, digits=3))

# Permutation Importance（分類スコアで・テストで）
r = permutation_importance(
    model,
    X_test, y_test,
    n_repeats=20,
    random_state=42,
    n_jobs=-1,
    scoring="f1_macro"
)

perm = pd.Series(r.importances_mean, index=X.columns).sort_values(ascending=False)

plt.figure(figsize=(8, 6))
perm.head(8).sort_values().plot.barh()
plt.title("Permutation Importance, scoring=f1)")
plt.xlabel("importance (ΔF1)")
plt.show()

class_rf_pred_perm = perm.head(20).to_dict()
# Out:
# y overall:
#  labels
# 0    727
# 1    555
# 2    276
# 3    218
# Name: count, dtype: int64
# y train:
#  labels
# 0    509
# 1    388
# 2    193
# 3    153
# Name: count, dtype: int64
# y test:
#  labels
# 0    218
# 1    167
# 2     83
# 3     65
# Name: count, dtype: int64
# confusion matrix:
#  [[209   0   1   8]
#  [  0 167   0   0]
#  [  0   0  83   0]
#  [  3   0   0  62]]
#               precision    recall  f1-score   support
#
#            0      0.986     0.959     0.972       218
#            1      1.000     1.000     1.000       167
#            2      0.988     1.000     0.994        83
#            3      0.886     0.954     0.919        65
#
#     accuracy                          0.977       533
#    macro avg      0.965     0.978     0.971       533
# weighted avg      0.978     0.977     0.978       533

# %% [markdown]
# ## モデルの確定と保存

# %%
#[70, 77, 49, 53, 58, 73]
feat_cols = [f"X{i}" for i in range(1,84)]

# %%
X = train[feat_cols]
y = train[f'labels']
X.head()
# Out:
#       X1    X2      X3    X4    X5    X6     X7    X8     X9   X10  ...  X74  \
# 0  22.98  1.37  797.20  0.67  0.15  0.08  67.15  9.86  37.23  0.94  ...  0.1
# 1  22.45  9.40  803.80  0.68  0.15  0.08  56.11  5.27  33.98  0.96  ...  0.1
# 2  22.03  1.14  594.52  0.64  0.14  0.08  51.57  6.15  10.44  0.94  ...  0.1
# 3  22.98  1.37  797.20  0.67  0.15  0.08  67.15  9.86  37.23  0.94  ...  0.1
# 4  22.98  1.37  797.20  0.67  0.15  0.08  67.15  9.86  37.23  0.94  ...  0.1
#
#     X75  X76   X77  X78  X79  X80   X81   X82   X83
# 0  0.04  6.4  0.58  0.0  4.1  0.0  0.01  0.16  0.04
# 1  0.04  6.4  0.58  0.0  4.1  0.0  0.01  0.16  0.04
# 2  0.04  6.4  0.58  0.0  4.1  0.0  0.01  0.16  0.04
# 3  0.04  6.4  0.58  0.0  4.1  0.0  0.01  0.16  0.04
# 4  0.04  6.4  0.58  0.0  4.1  0.0  0.01  0.16  0.04
#
# [5 rows x 83 columns]

# %%
model = RandomForestClassifier(
    n_estimators=300,
    random_state=42,
    class_weight="balanced"   # 不均衡対策（効くこと多い）
)

model.fit(X, y)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=300,
#                        random_state=42)

# %%
test= raw_data[-500:]
X_test = test[feat_cols]

X_test = X_test.copy()
X_test["pred_labels"] = model.predict(X_test)

# %%
for i in range(cluster_num):
    plt.figure(figsize=(9, 4))
    plt.plot(
        test.index,
        test["OV"],
        label='Actual OV',
        color='red',
        linestyle='--',
        alpha=0.3
    )
    # labelsが1のみフィルタしてプロット
    mask = X_test["pred_labels"] == i
    plt.scatter(
        X_test.index[mask],
        test["OV"][mask],
        c=X_test["pred_labels"][mask],
        cmap="tab10",
        s=10,
        zorder=2
    )

    plt.xlabel("record index")
    plt.ylabel("OV")
    plt.title(f"OV[cluster id:{i}] by record (colored by batch cluster)")
    plt.colorbar(label="cluster")

    plt.show()

# %%
# モデルをファイルに保存
with open('../data/model/class_rf_model.pkl', 'wb') as f:
    pickle.dump(model, f)

# %%
# Permutation Importance（分類スコアで・テストで）
r = permutation_importance(
    model,
    X_test, y_test,
    n_repeats=20,
    random_state=42,
    n_jobs=-1,
    scoring="f1_macro"
)

perm = pd.Series(r.importances_mean, index=X.columns).sort_values(ascending=False)

plt.figure(figsize=(8, 6))
perm.head(8).sort_values().plot.barh()
plt.title("Permutation Importance, scoring=f1)")
plt.xlabel("importance (ΔF1)")
plt.show()

class_rf_pred_perm = perm.head(20).to_dict()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[101], line 2
#       1 # Permutation Importance（分類スコアで・テストで）
# ----> 2 r = permutation_importance(
#       3     model,
#       4     X_test, y_test,
#       5     n_repeats=20,
#       6     random_state=42,
#       7     n_jobs=-1,
#       8     scoring="f1_macro"
#       9 )
#      11 perm = pd.Series(r.importances_mean, index=X.columns).sort_values(ascending=False)
#      13 plt.figure(figsize=(8, 6))
#
# File ~/Develop/ass-production-management2/.venv/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~/Develop/ass-production-management2/.venv/lib/python3.12/site-packages/sklearn/inspection/_permutation_importance.py:290, in permutation_importance(estimator, X, y, scoring, n_repeats, n_jobs, random_state, sample_weight, max_samples)
#     287     scorers_dict = _check_multimetric_scoring(estimator, scoring)
#     288     scorer = _MultimetricScorer(scorers=scorers_dict)
# --> 290 baseline_score = _weights_scorer(scorer, estimator, X, y, sample_weight)
#     292 scores = Parallel(n_jobs=n_jobs)(
#     293     delayed(_calculate_permutation_scores)(
#     294         estimator,
#    (...)    304     for col_idx in range(X.shape[1])
#     305 )
#     307 if isinstance(baseline_score, dict):
#
# File ~/Develop/ass-production-management2/.venv/lib/python3.12/site-packages/sklearn/inspection/_permutation_importance.py:26, in _weights_scorer(scorer, estimator, X, y, sample_weight)
#      24 if sample_weight is not None:
#      25     return scorer(estimator, X, y, sample_weight=sample_weight)
# ---> 26 return scorer(estimator, X, y)
#
# File ~/Develop/ass-production-management2/.venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py:253, in _BaseScorer.__call__(self, estimator, X, y_true, sample_weight, **kwargs)
#     250 if sample_weight is not None:
#     251     _kwargs["sample_weight"] = sample_weight
# --> 253 return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#
# File ~/Develop/ass-production-management2/.venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py:345, in _Scorer._score(self, method_caller, estimator, X, y_true, **kwargs)
#     343 pos_label = None if is_regressor(estimator) else self._get_pos_label()
#     344 response_method = _check_response_method(estimator, self._response_method)
# --> 345 y_pred = method_caller(
#     346     estimator, response_method.__name__, X, pos_label=pos_label
#     347 )
#     349 scoring_kwargs = {**self._kwargs, **kwargs}
#     350 return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#
# File ~/Develop/ass-production-management2/.venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py:87, in _cached_call(cache, estimator, response_method, *args, **kwargs)
#      84 if cache is not None and response_method in cache:
#      85     return cache[response_method]
# ---> 87 result, _ = _get_response_values(
#      88     estimator, *args, response_method=response_method, **kwargs
#      89 )
#      91 if cache is not None:
#      92     cache[response_method] = result
#
# File ~/Develop/ass-production-management2/.venv/lib/python3.12/site-packages/sklearn/utils/_response.py:210, in _get_response_values(estimator, X, response_method, pos_label, return_response_method_used)
#     207     elif pos_label is None and target_type == "binary":
#     208         pos_label = classes[-1]
# --> 210 y_pred = prediction_method(X)
#     212 if prediction_method.__name__ in ("predict_proba", "predict_log_proba"):
#     213     y_pred = _process_predict_proba(
#     214         y_pred=y_pred,
#     215         target_type=target_type,
#     216         classes=classes,
#     217         pos_label=pos_label,
#     218     )
#
# File ~/Develop/ass-production-management2/.venv/lib/python3.12/site-packages/sklearn/ensemble/_forest.py:905, in ForestClassifier.predict(self, X)
#     884 def predict(self, X):
#     885     """
#     886     Predict class for X.
#     887
#    (...)    903         The predicted classes.
#     904     """
# --> 905     proba = self.predict_proba(X)
#     907     if self.n_outputs_ == 1:
#     908         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File ~/Develop/ass-production-management2/.venv/lib/python3.12/site-packages/sklearn/ensemble/_forest.py:947, in ForestClassifier.predict_proba(self, X)
#     945 check_is_fitted(self)
#     946 # Check data
# --> 947 X = self._validate_X_predict(X)
#     949 # Assign chunk of trees to jobs
#     950 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File ~/Develop/ass-production-management2/.venv/lib/python3.12/site-packages/sklearn/ensemble/_forest.py:641, in BaseForest._validate_X_predict(self, X)
#     638 else:
#     639     force_all_finite = True
# --> 641 X = self._validate_data(
#     642     X,
#     643     dtype=DTYPE,
#     644     accept_sparse="csr",
#     645     reset=False,
#     646     force_all_finite=force_all_finite,
#     647 )
#     648 if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
#     649     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File ~/Develop/ass-production-management2/.venv/lib/python3.12/site-packages/sklearn/base.py:608, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     537 def _validate_data(
#     538     self,
#     539     X="no_validation",
#    (...)    544     **check_params,
#     545 ):
#     546     """Validate input data and set or check the `n_features_in_` attribute.
#     547
#     548     Parameters
#    (...)    606         validated.
#     607     """
# --> 608     self._check_feature_names(X, reset=reset)
#     610     if y is None and self._get_tags()["requires_y"]:
#     611         raise ValueError(
#     612             f"This {self.__class__.__name__} estimator "
#     613             "requires y to be passed, but the target y is None."
#     614         )
#
# File ~/Develop/ass-production-management2/.venv/lib/python3.12/site-packages/sklearn/base.py:535, in BaseEstimator._check_feature_names(self, X, reset)
#     530 if not missing_names and not unexpected_names:
#     531     message += (
#     532         "Feature names must be in the same order as they were in fit.\n"
#     533     )
# --> 535 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - pred_labels
# Exception ignored in: <function ResourceTracker.__del__ at 0x1091cba60>
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x1070e7a60>
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x10bb3fa60>
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x10b557a60>
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x10bacba60>
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x10b56fa60>
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x109667a60>
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x109767a60>
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x10b7d3a60>
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x10909fa60>
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
